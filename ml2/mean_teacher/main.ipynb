# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4 * 4 * 50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4 * 4 * 50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def train(args, model, mean_teacher, device, train_loader, test_loader, optimizer, epoch):
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()

        output = model(data)

        ########################### CODE CHANGE HERE ######################################
        # forward pass with mean teacher
        # torch.no_grad() prevents gradients from being passed into mean teacher model
        with torch.no_grad():
            mean_t_output = mean_teacher(data)

        ########################### CODE CHANGE HERE ######################################
        # consistency loss (example with MSE, you can change)
        const_loss = F.mse_loss(output, mean_t_output)

        ########################### CODE CHANGE HERE ######################################
        # set the consistency weight (should schedule)
        weight = 0.2
        loss = F.nll_loss(output, target) + weight*const_loss
        loss.backward()
        optimizer.step()

        ########################### CODE CHANGE HERE ######################################
        # update mean teacher, (should choose alpha somehow)
        # Use the true average until the exponential average is more correct
        alpha = 0.95
        for mean_param, param in zip(mean_teacher.parameters(), model.parameters()):
            mean_param.data.mul_(alpha).add_(1 - alpha, param.data)

        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item()))
            test(args, model, device, test_loader)
            test(args, mean_teacher, device, test_loader)

# %%
def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    model.train()

# %%
parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
parser.add_argument('--batch-size', type=int, default=64, metavar='N',
                    help='input batch size for training (default: 64)')
parser.add_argument('--test-batch-size', type=int, default=1000, metavar='N',
                    help='input batch size for testing (default: 1000)')
parser.add_argument('--epochs', type=int, default=10, metavar='N',
                    help='number of epochs to train (default: 10)')
parser.add_argument('--lr', type=float, default=0.01, metavar='LR',
                    help='learning rate (default: 0.01)')
parser.add_argument('--momentum', type=float, default=0.5, metavar='M',
                    help='SGD momentum (default: 0.5)')
parser.add_argument('--no-cuda', action='store_true', default=False,
                    help='disables CUDA training')
parser.add_argument('--seed', type=int, default=1, metavar='S',
                    help='random seed (default: 1)')
parser.add_argument('--log-interval', type=int, default=100, metavar='N',
                    help='how many batches to wait before logging training status')

parser.add_argument('--save-model', action='store_true', default=False,
                    help='For Saving the current Model')
parser.add_argument('-f')
args = parser.parse_args()
use_cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=args.batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])),
    batch_size=args.test_batch_size, shuffle=True, **kwargs)

model = Net().to(device)
########################### CODE CHANGE HERE ######################################
# initialize mean teacher
mean_teacher = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)

for epoch in range(1, args.epochs + 1):
    train(args, model, mean_teacher, device, train_loader, test_loader, optimizer, epoch)

if (args.save_model):
    torch.save(model.state_dict(), "mnist_cnn.pt")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.296516
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
# Test set: Average loss: 2.2992, Accuracy: 915/10000 (9%)
#
#
# Test set: Average loss: 2.3035, Accuracy: 994/10000 (10%)
#
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.925068
#
# Test set: Average loss: 0.7739, Accuracy: 8485/10000 (85%)
#
#
# Test set: Average loss: 0.9535, Accuracy: 8341/10000 (83%)
#
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.475888
#
# Test set: Average loss: 0.4219, Accuracy: 9096/10000 (91%)
#
#
# Test set: Average loss: 0.4484, Accuracy: 9136/10000 (91%)
#
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.250499
#
# Test set: Average loss: 0.3032, Accuracy: 9273/10000 (93%)
#
#
# Test set: Average loss: 0.3059, Accuracy: 9364/10000 (94%)
#
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.225821
#
# Test set: Average loss: 0.2312, Accuracy: 9498/10000 (95%)
#
#
# Test set: Average loss: 0.2341, Accuracy: 9492/10000 (95%)
#
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.223835
#
# Test set: Average loss: 0.1868, Accuracy: 9595/10000 (96%)
#
#
# Test set: Average loss: 0.1904, Accuracy: 9590/10000 (96%)
#
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.102862
#
# Test set: Average loss: 0.1595, Accuracy: 9644/10000 (96%)
#
#
# Test set: Average loss: 0.1615, Accuracy: 9641/10000 (96%)
#
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.148654
#
# Test set: Average loss: 0.1395, Accuracy: 9680/10000 (97%)
#
#
# Test set: Average loss: 0.1411, Accuracy: 9675/10000 (97%)
#
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.125732
#
# Test set: Average loss: 0.1274, Accuracy: 9704/10000 (97%)
#
#
# Test set: Average loss: 0.1263, Accuracy: 9716/10000 (97%)
#
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.148826
#
# Test set: Average loss: 0.1151, Accuracy: 9732/10000 (97%)
#
#
# Test set: Average loss: 0.1153, Accuracy: 9742/10000 (97%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.146603
#
# Test set: Average loss: 0.1124, Accuracy: 9737/10000 (97%)
#
#
# Test set: Average loss: 0.1109, Accuracy: 9752/10000 (98%)
#
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.129811
#
# Test set: Average loss: 0.1015, Accuracy: 9762/10000 (98%)
#
#
# Test set: Average loss: 0.1015, Accuracy: 9766/10000 (98%)
#
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.046219
#
# Test set: Average loss: 0.0937, Accuracy: 9784/10000 (98%)
#
#
# Test set: Average loss: 0.0943, Accuracy: 9781/10000 (98%)
#
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.102888
#
# Test set: Average loss: 0.0881, Accuracy: 9791/10000 (98%)
#
#
# Test set: Average loss: 0.0881, Accuracy: 9788/10000 (98%)
#
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.114979
#
# Test set: Average loss: 0.0831, Accuracy: 9791/10000 (98%)
#
#
# Test set: Average loss: 0.0833, Accuracy: 9793/10000 (98%)
#
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.086526
#
# Test set: Average loss: 0.0781, Accuracy: 9807/10000 (98%)
#
#
# Test set: Average loss: 0.0786, Accuracy: 9812/10000 (98%)
#
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.107534
#
# Test set: Average loss: 0.0777, Accuracy: 9814/10000 (98%)
#
#
# Test set: Average loss: 0.0747, Accuracy: 9820/10000 (98%)
#
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.094603
#
# Test set: Average loss: 0.0715, Accuracy: 9820/10000 (98%)
#
#
# Test set: Average loss: 0.0714, Accuracy: 9827/10000 (98%)
#
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.049429
#
# Test set: Average loss: 0.0690, Accuracy: 9829/10000 (98%)
#
#
# Test set: Average loss: 0.0683, Accuracy: 9826/10000 (98%)
#
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.056733
#
# Test set: Average loss: 0.0658, Accuracy: 9830/10000 (98%)
#
#
# Test set: Average loss: 0.0664, Accuracy: 9834/10000 (98%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.056934
#
# Test set: Average loss: 0.0649, Accuracy: 9836/10000 (98%)
#
#
# Test set: Average loss: 0.0650, Accuracy: 9830/10000 (98%)
#
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 0.073834
#
# Test set: Average loss: 0.0624, Accuracy: 9842/10000 (98%)
#
#
# Test set: Average loss: 0.0629, Accuracy: 9838/10000 (98%)
#
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.073711
#
# Test set: Average loss: 0.0618, Accuracy: 9843/10000 (98%)
#
#
# Test set: Average loss: 0.0603, Accuracy: 9851/10000 (99%)
#
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.041308
#
# Test set: Average loss: 0.0588, Accuracy: 9848/10000 (98%)
#
#
# Test set: Average loss: 0.0584, Accuracy: 9847/10000 (98%)
#
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.069286
#
# Test set: Average loss: 0.0582, Accuracy: 9843/10000 (98%)
#
#
# Test set: Average loss: 0.0571, Accuracy: 9849/10000 (98%)
#
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.066433
#
# Test set: Average loss: 0.0567, Accuracy: 9840/10000 (98%)
#
#
# Test set: Average loss: 0.0555, Accuracy: 9857/10000 (99%)
#
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.104936
#
# Test set: Average loss: 0.0538, Accuracy: 9861/10000 (99%)
#
#
# Test set: Average loss: 0.0542, Accuracy: 9864/10000 (99%)
#
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 0.106320
#
# Test set: Average loss: 0.0541, Accuracy: 9863/10000 (99%)
#
#
# Test set: Average loss: 0.0527, Accuracy: 9866/10000 (99%)
#
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.019582
#
# Test set: Average loss: 0.0513, Accuracy: 9863/10000 (99%)
#
#
# Test set: Average loss: 0.0509, Accuracy: 9866/10000 (99%)
#
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.098489
#
# Test set: Average loss: 0.0500, Accuracy: 9864/10000 (99%)
#
#
# Test set: Average loss: 0.0496, Accuracy: 9870/10000 (99%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.128977
#
# Test set: Average loss: 0.0498, Accuracy: 9874/10000 (99%)
#
#
# Test set: Average loss: 0.0490, Accuracy: 9874/10000 (99%)
#
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 0.062863
#
# Test set: Average loss: 0.0486, Accuracy: 9876/10000 (99%)
#
#
# Test set: Average loss: 0.0481, Accuracy: 9874/10000 (99%)
#
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.039202
#
# Test set: Average loss: 0.0478, Accuracy: 9876/10000 (99%)
#
#
# Test set: Average loss: 0.0475, Accuracy: 9874/10000 (99%)
#
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.024824
#
# Test set: Average loss: 0.0459, Accuracy: 9881/10000 (99%)
#
#
# Test set: Average loss: 0.0459, Accuracy: 9880/10000 (99%)
#
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.029657
#
# Test set: Average loss: 0.0451, Accuracy: 9881/10000 (99%)
#
#
# Test set: Average loss: 0.0448, Accuracy: 9887/10000 (99%)
#
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.053115
#
# Test set: Average loss: 0.0443, Accuracy: 9884/10000 (99%)
#
#
# Test set: Average loss: 0.0440, Accuracy: 9883/10000 (99%)
#
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.057379
#
# Test set: Average loss: 0.0440, Accuracy: 9878/10000 (99%)
#
#
# Test set: Average loss: 0.0433, Accuracy: 9881/10000 (99%)
#
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 0.065940
#
# Test set: Average loss: 0.0444, Accuracy: 9881/10000 (99%)
#
#
# Test set: Average loss: 0.0427, Accuracy: 9882/10000 (99%)
#
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.048889
#
# Test set: Average loss: 0.0434, Accuracy: 9880/10000 (99%)
#
#
# Test set: Average loss: 0.0421, Accuracy: 9886/10000 (99%)
#
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.039223
#
# Test set: Average loss: 0.0413, Accuracy: 9885/10000 (99%)
#
#
# Test set: Average loss: 0.0412, Accuracy: 9889/10000 (99%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.078847
#
# Test set: Average loss: 0.0420, Accuracy: 9886/10000 (99%)
#
#
# Test set: Average loss: 0.0413, Accuracy: 9888/10000 (99%)
#
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 0.026734
#
# Test set: Average loss: 0.0406, Accuracy: 9885/10000 (99%)
#
#
# Test set: Average loss: 0.0406, Accuracy: 9888/10000 (99%)
#
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.032124
#
# Test set: Average loss: 0.0409, Accuracy: 9881/10000 (99%)
#
#
# Test set: Average loss: 0.0402, Accuracy: 9884/10000 (99%)
#
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 0.030309
#
# Test set: Average loss: 0.0393, Accuracy: 9888/10000 (99%)
#
#
# Test set: Average loss: 0.0395, Accuracy: 9892/10000 (99%)
#
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.073856
#
# Test set: Average loss: 0.0394, Accuracy: 9891/10000 (99%)
#
#
# Test set: Average loss: 0.0388, Accuracy: 9887/10000 (99%)
#
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.034873
#
# Test set: Average loss: 0.0383, Accuracy: 9889/10000 (99%)
#
#
# Test set: Average loss: 0.0381, Accuracy: 9893/10000 (99%)
#
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.052100
#
# Test set: Average loss: 0.0378, Accuracy: 9888/10000 (99%)
#
#
# Test set: Average loss: 0.0374, Accuracy: 9889/10000 (99%)
#
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 0.019062
#
# Test set: Average loss: 0.0376, Accuracy: 9887/10000 (99%)
#
#
# Test set: Average loss: 0.0368, Accuracy: 9892/10000 (99%)
#
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.031115
#
# Test set: Average loss: 0.0363, Accuracy: 9894/10000 (99%)
#
#
# Test set: Average loss: 0.0364, Accuracy: 9891/10000 (99%)
#
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.025013
#
# Test set: Average loss: 0.0356, Accuracy: 9900/10000 (99%)
#
#
# Test set: Average loss: 0.0356, Accuracy: 9903/10000 (99%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.077054
#
# Test set: Average loss: 0.0365, Accuracy: 9898/10000 (99%)
#
#
# Test set: Average loss: 0.0354, Accuracy: 9903/10000 (99%)
#
# Train Epoch: 6 [6400/60000 (11%)]	Loss: 0.029100
#
# Test set: Average loss: 0.0350, Accuracy: 9895/10000 (99%)
#
#
# Test set: Average loss: 0.0349, Accuracy: 9899/10000 (99%)
#
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.064579
#
# Test set: Average loss: 0.0350, Accuracy: 9895/10000 (99%)
#
#
# Test set: Average loss: 0.0348, Accuracy: 9897/10000 (99%)
#
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 0.012911
#
# Test set: Average loss: 0.0351, Accuracy: 9901/10000 (99%)
#
#
# Test set: Average loss: 0.0348, Accuracy: 9895/10000 (99%)
#
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.037655
#
# Test set: Average loss: 0.0347, Accuracy: 9896/10000 (99%)
#
#
# Test set: Average loss: 0.0347, Accuracy: 9902/10000 (99%)
#
# Train Epoch: 6 [32000/60000 (53%)]	Loss: 0.014780
#
# Test set: Average loss: 0.0342, Accuracy: 9898/10000 (99%)
#
#
# Test set: Average loss: 0.0341, Accuracy: 9902/10000 (99%)
#
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.016646
#
# Test set: Average loss: 0.0336, Accuracy: 9906/10000 (99%)
#
#
# Test set: Average loss: 0.0338, Accuracy: 9904/10000 (99%)
#
# Train Epoch: 6 [44800/60000 (75%)]	Loss: 0.051141
#
# Test set: Average loss: 0.0335, Accuracy: 9904/10000 (99%)
#
#
# Test set: Average loss: 0.0331, Accuracy: 9908/10000 (99%)
#
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.038618
#
# Test set: Average loss: 0.0325, Accuracy: 9907/10000 (99%)
#
#
# Test set: Average loss: 0.0327, Accuracy: 9907/10000 (99%)
#
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 0.037313
#
# Test set: Average loss: 0.0330, Accuracy: 9902/10000 (99%)
#
#
# Test set: Average loss: 0.0324, Accuracy: 9904/10000 (99%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.016763
#
# Test set: Average loss: 0.0326, Accuracy: 9906/10000 (99%)
#
#
# Test set: Average loss: 0.0323, Accuracy: 9904/10000 (99%)
#
# Train Epoch: 7 [6400/60000 (11%)]	Loss: 0.037305
#
# Test set: Average loss: 0.0322, Accuracy: 9906/10000 (99%)
#
#
# Test set: Average loss: 0.0322, Accuracy: 9907/10000 (99%)
#
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.028668
#
# Test set: Average loss: 0.0321, Accuracy: 9909/10000 (99%)
#
#
# Test set: Average loss: 0.0318, Accuracy: 9907/10000 (99%)
#
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 0.125642
#
# Test set: Average loss: 0.0324, Accuracy: 9906/10000 (99%)
#
#
# Test set: Average loss: 0.0320, Accuracy: 9908/10000 (99%)
#
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.066628
#
# Test set: Average loss: 0.0321, Accuracy: 9897/10000 (99%)
#
#
# Test set: Average loss: 0.0319, Accuracy: 9908/10000 (99%)
#
# Train Epoch: 7 [32000/60000 (53%)]	Loss: 0.014763
#
# Test set: Average loss: 0.0315, Accuracy: 9911/10000 (99%)
#
#
# Test set: Average loss: 0.0314, Accuracy: 9909/10000 (99%)
#
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.016464
#
# Test set: Average loss: 0.0313, Accuracy: 9906/10000 (99%)
#
#
# Test set: Average loss: 0.0310, Accuracy: 9906/10000 (99%)
#
# Train Epoch: 7 [44800/60000 (75%)]	Loss: 0.046683
#
# Test set: Average loss: 0.0308, Accuracy: 9905/10000 (99%)
#
#
# Test set: Average loss: 0.0307, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.013058
#
# Test set: Average loss: 0.0306, Accuracy: 9909/10000 (99%)
#
#
# Test set: Average loss: 0.0307, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 0.014899
#
# Test set: Average loss: 0.0305, Accuracy: 9912/10000 (99%)
#
#
# Test set: Average loss: 0.0303, Accuracy: 9912/10000 (99%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.018880
#
# Test set: Average loss: 0.0305, Accuracy: 9910/10000 (99%)
#
#
# Test set: Average loss: 0.0305, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 8 [6400/60000 (11%)]	Loss: 0.018781
#
# Test set: Average loss: 0.0304, Accuracy: 9912/10000 (99%)
#
#
# Test set: Average loss: 0.0302, Accuracy: 9907/10000 (99%)
#
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.037359
#
# Test set: Average loss: 0.0305, Accuracy: 9908/10000 (99%)
#
#
# Test set: Average loss: 0.0299, Accuracy: 9911/10000 (99%)
#
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 0.044284
#
# Test set: Average loss: 0.0303, Accuracy: 9911/10000 (99%)
#
#
# Test set: Average loss: 0.0296, Accuracy: 9909/10000 (99%)
#
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.012170
#
# Test set: Average loss: 0.0297, Accuracy: 9918/10000 (99%)
#
#
# Test set: Average loss: 0.0293, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 8 [32000/60000 (53%)]	Loss: 0.017615
#
# Test set: Average loss: 0.0295, Accuracy: 9915/10000 (99%)
#
#
# Test set: Average loss: 0.0294, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.025550
#
# Test set: Average loss: 0.0296, Accuracy: 9909/10000 (99%)
#
#
# Test set: Average loss: 0.0293, Accuracy: 9911/10000 (99%)
#
# Train Epoch: 8 [44800/60000 (75%)]	Loss: 0.022330
#
# Test set: Average loss: 0.0293, Accuracy: 9910/10000 (99%)
#
#
# Test set: Average loss: 0.0290, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.028072
#
# Test set: Average loss: 0.0289, Accuracy: 9915/10000 (99%)
#
#
# Test set: Average loss: 0.0286, Accuracy: 9916/10000 (99%)
#
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 0.024357
#
# Test set: Average loss: 0.0283, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0281, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.047824
#
# Test set: Average loss: 0.0285, Accuracy: 9916/10000 (99%)
#
#
# Test set: Average loss: 0.0281, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 9 [6400/60000 (11%)]	Loss: 0.042235
#
# Test set: Average loss: 0.0284, Accuracy: 9915/10000 (99%)
#
#
# Test set: Average loss: 0.0280, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.008605
#
# Test set: Average loss: 0.0280, Accuracy: 9921/10000 (99%)
#
#
# Test set: Average loss: 0.0280, Accuracy: 9920/10000 (99%)
#
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 0.018059
#
# Test set: Average loss: 0.0284, Accuracy: 9916/10000 (99%)
#
#
# Test set: Average loss: 0.0280, Accuracy: 9920/10000 (99%)
#
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.026764
#
# Test set: Average loss: 0.0281, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0279, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 0.016423
#
# Test set: Average loss: 0.0277, Accuracy: 9919/10000 (99%)
#
#
# Test set: Average loss: 0.0274, Accuracy: 9916/10000 (99%)
#
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.047927
#
# Test set: Average loss: 0.0276, Accuracy: 9911/10000 (99%)
#
#
# Test set: Average loss: 0.0274, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 9 [44800/60000 (75%)]	Loss: 0.023061
#
# Test set: Average loss: 0.0271, Accuracy: 9917/10000 (99%)
#
#
# Test set: Average loss: 0.0269, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.018536
#
# Test set: Average loss: 0.0272, Accuracy: 9918/10000 (99%)
#
#
# Test set: Average loss: 0.0270, Accuracy: 9920/10000 (99%)
#
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.034317
#
# Test set: Average loss: 0.0268, Accuracy: 9921/10000 (99%)
#
#
# Test set: Average loss: 0.0267, Accuracy: 9919/10000 (99%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.018329
#
# Test set: Average loss: 0.0266, Accuracy: 9922/10000 (99%)
#
#
# Test set: Average loss: 0.0264, Accuracy: 9921/10000 (99%)
#
# Train Epoch: 10 [6400/60000 (11%)]	Loss: 0.014739
#
# Test set: Average loss: 0.0265, Accuracy: 9926/10000 (99%)
#
#
# Test set: Average loss: 0.0264, Accuracy: 9926/10000 (99%)
#
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.013955
#
# Test set: Average loss: 0.0263, Accuracy: 9921/10000 (99%)
#
#
# Test set: Average loss: 0.0262, Accuracy: 9925/10000 (99%)
#
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 0.036167
#
# Test set: Average loss: 0.0264, Accuracy: 9916/10000 (99%)
#
#
# Test set: Average loss: 0.0258, Accuracy: 9924/10000 (99%)
#
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.040084
#
# Test set: Average loss: 0.0258, Accuracy: 9920/10000 (99%)
#
#
# Test set: Average loss: 0.0257, Accuracy: 9920/10000 (99%)
#
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 0.010260
#
# Test set: Average loss: 0.0257, Accuracy: 9921/10000 (99%)
#
#
# Test set: Average loss: 0.0258, Accuracy: 9922/10000 (99%)
#
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.007235
#
# Test set: Average loss: 0.0260, Accuracy: 9923/10000 (99%)
#
#
# Test set: Average loss: 0.0257, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 10 [44800/60000 (75%)]	Loss: 0.011238
#
# Test set: Average loss: 0.0262, Accuracy: 9924/10000 (99%)
#
#
# Test set: Average loss: 0.0260, Accuracy: 9925/10000 (99%)
#
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.018065
#
# Test set: Average loss: 0.0262, Accuracy: 9927/10000 (99%)
#
#
# Test set: Average loss: 0.0261, Accuracy: 9927/10000 (99%)
#
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.024563
#
# Test set: Average loss: 0.0263, Accuracy: 9925/10000 (99%)
#
#
# Test set: Average loss: 0.0259, Accuracy: 9928/10000 (99%)
