# %%
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # 배치를 제외한 모든 차원을 평탄화(flatten)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
def test(model, device, test_loader, model_name):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('{} Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        model_name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    model.train()

# %%
def train(args, model, mean_teacher, device, train_loader, test_loader, optimizer, epoch):
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()

        output = model(data)

        with torch.no_grad():
            mean_t_output = mean_teacher(data)

        const_loss = F.mse_loss(output, mean_t_output)

        weight = 0.2
        loss = F.nll_loss(output, target) + weight*const_loss
        loss.backward()
        optimizer.step()

        alpha = 0.95
        for mean_param, param in zip(mean_teacher.parameters(), model.parameters()):
            mean_param.data.mul_(alpha).add_(1 - alpha, param.data)

        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss.item()))
            test(model, device, test_loader, "STUDENT")
            test(mean_teacher, device, test_loader, "MEAN_TEACHER")
            print()

# %%
def main():
    parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
    parser.add_argument('--batch-size', type=int, default=64, metavar='N',
                        help='input batch size for training (default: 64)')
    parser.add_argument('--test-batch-size', type=int, default=1000, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=10, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.01, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.5, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=False,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=100, metavar='N',
                        help='how many batches to wait before logging training status')

    parser.add_argument('--save-model', action='store_true', default=False,
                        help='For Saving the current Model')
    parser.add_argument('-f')

    args = parser.parse_args()
    use_cuda = not args.no_cuda and torch.cuda.is_available()

    torch.manual_seed(args.seed)

    device = torch.device("cuda" if use_cuda else "cpu")

    kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
    train_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('../data', train=True, download=True,
                       transform=transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(p=0.3),
        transforms.RandomVerticalFlip(p=0.3),
        transforms.GaussianBlur(3),
        transforms.RandomErasing(p=0.3),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]
)),
        batch_size=args.batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('../data', train=False, transform=transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(p=0.3),
        transforms.RandomVerticalFlip(p=0.3),
        transforms.GaussianBlur(3),
        transforms.RandomErasing(p=0.3),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]
)),
        batch_size=args.test_batch_size, shuffle=True, **kwargs)

    model = Net().to(device)

    mean_teacher = Net().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)

    for epoch in range(1, args.epochs + 1):
        train(args, model, mean_teacher, device, train_loader, test_loader, optimizer, epoch)

    if (args.save_model):
        torch.save(model.state_dict(), "cifar10_cnn.pt")

# %%
if __name__ == '__main__':
    main()
# Out:
# Files already downloaded and verified
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.299417
# STUDENT Test set: Average loss: 2.3038, Accuracy: 965/10000 (10%)
# MEAN_TEACHER Test set: Average loss: 2.3047, Accuracy: 990/10000 (10%)
#
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 2.302548
# STUDENT Test set: Average loss: 2.3026, Accuracy: 1012/10000 (10%)
# MEAN_TEACHER Test set: Average loss: 2.3028, Accuracy: 1077/10000 (11%)
#
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 2.305959
# STUDENT Test set: Average loss: 2.3013, Accuracy: 997/10000 (10%)
# MEAN_TEACHER Test set: Average loss: 2.3015, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 2.294536
# STUDENT Test set: Average loss: 2.2996, Accuracy: 1080/10000 (11%)
# MEAN_TEACHER Test set: Average loss: 2.3000, Accuracy: 1022/10000 (10%)
#
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 2.302563
# STUDENT Test set: Average loss: 2.2962, Accuracy: 1443/10000 (14%)
# MEAN_TEACHER Test set: Average loss: 2.2968, Accuracy: 1398/10000 (14%)
#
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 2.285920
# STUDENT Test set: Average loss: 2.2872, Accuracy: 1669/10000 (17%)
# MEAN_TEACHER Test set: Average loss: 2.2896, Accuracy: 1759/10000 (18%)
#
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 2.251162
# STUDENT Test set: Average loss: 2.2617, Accuracy: 1574/10000 (16%)
# MEAN_TEACHER Test set: Average loss: 2.2686, Accuracy: 1695/10000 (17%)
#
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 2.229339
# STUDENT Test set: Average loss: 2.2222, Accuracy: 1859/10000 (19%)
# MEAN_TEACHER Test set: Average loss: 2.2286, Accuracy: 1831/10000 (18%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.161202
# STUDENT Test set: Average loss: 2.1837, Accuracy: 2038/10000 (20%)
# MEAN_TEACHER Test set: Average loss: 2.1943, Accuracy: 2061/10000 (21%)
#
# Train Epoch: 2 [6400/50000 (13%)]	Loss:
# Train Epoch: 4 [19200/50000 (38%)]	Loss: 1.688906
# STUDENT Test set: Average loss: 1.7802, Accuracy: 3463/10000 (35%)
# MEAN_TEACHER Test set: Average loss: 1.7794, Accuracy: 3472/10000 (35%)
#
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.797838
# STUDENT Test set: Average loss: 1.7765, Accuracy: 3454/10000 (35%)
# MEAN_TEACHER Test set: Average loss: 1.7587, Accuracy: 3573/10000 (36%)
#
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 1.807631
# STUDENT Test set: Average loss: 1.7605, Accuracy: 3542/10000 (35%)
# MEAN_TEACHER Test set: Average loss: 1.7525, Accuracy: 3614/10000 (36%)
#
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.688731
# STUDENT Test set: Average loss: 1.7472, Accuracy: 3673/10000 (37%)
# MEAN_TEACHER Test set: Average loss: 1.7477, Accuracy: 3630/10000 (36%)
#
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 1.678373
# STUDENT Test set: Average loss: 1.7268, Accuracy: 3660/10000 (37%)
# MEAN_TEACHER Test set: Average loss: 1.7277, Accuracy: 3683/10000 (37%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.612154
# STUDENT Test set: Average loss: 1.7542, Accuracy: 3591/10000 (36%)
# MEAN_TEACHER Test set: Average loss: 1.7259, Accuracy: 3631/10000 (36%)
#
# Train Epoch: 5 [6400/50000 (13%)]	Loss: 1.523111
# STUDENT Test set: Average loss: 1.7298, Accuracy: 3665/10000 (37%)
# MEAN_TEACHER Test set: Average loss: 1.7165, Accuracy: 3809/10000 (38%)
#
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 1.563094
# STUDENT Test set: Average loss: 1.7199, Accuracy: 3730/10000 (37%)
# MEAN_TEACHER Test set: Average loss: 1.7092, Accuracy: 3755/10000 (38%)
#
# Train Epoch: 5 [19200/50000 (38%)]	Loss: 1.655365
# STUDENT Test set: Average loss: 1.7350, Accuracy: 3694/10000 (37%)
# MEAN_TEACHER Test set: Average loss: 1.7019, Accuracy: 3785/10000 (38%)
#
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.922724
# STUDENT Test set: Average loss: 1.7140, Accuracy: 3811/10000 (38%)
# MEAN_TEACHER Test set: Average loss: 1.6927, Accuracy: 3825/10000 (38%)
#
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 1.722173
# STUDENT Test set: Average loss: 1.6991, Accuracy: 3916/10000 (39%)
# MEAN_TEACHER Test set: Average loss: 1.6778, Accuracy: 3968/10000 (40%)
#
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.799822
# STUDENT Test set: Average loss: 1.6870, Accuracy: 3805/10000 (38%)
# MEAN_TEACHER Test set: Average loss: 1.6766, Accuracy: 3949/10000 (39%)
#
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 1.644972
# STUDENT Test set: Average loss: 1.6856, Accuracy: 3916/10000 (39%)
# MEAN_TEACHER Test set: Average loss: 1.6682, Accuracy: 3949/10000 (39%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.743456
# STUDENT Test set: Average loss: 1.6757, Accuracy: 3919/10000 (39%)
# MEAN_TEACHER Test set: Average loss: 1.6649, Accuracy: 3955/10000 (40%)
#
# Train Epoch: 6 [6400/50000 (13%)]	Loss: 2.028415
# STUDENT Test set: Average loss: 1.6762, Accuracy: 3896/10000 (39%)
# MEAN_TEACHER Test set: Average loss: 1.6569, Accuracy: 3994/10000 (40%)
#
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 1.711907
# STUDENT Test set: Average loss: 1.6719, Accuracy: 3971/10000 (40%)
# MEAN_TEACHER Test set: Average loss: 1.6486, Accuracy: 4114/10000 (41%)
#
# Train Epoch: 6 [19200/50000 (38%)]	Loss: 1.994736
# STUDENT Test set: Average loss: 1.6539, Accuracy: 3973/10000 (40%)
# MEAN_TEACHER Test set: Average loss: 1.6414, Accuracy: 4076/10000 (41%)
#
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.786630
# STUDENT Test set: Average loss: 1.6893, Accuracy: 3898/10000 (39%)
# MEAN_TEACHER Test set: Average loss: 1.6288, Accuracy: 4134/10000 (41%)
#
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 1.914129
# STUDENT Test set: Average loss: 1.6412, Accuracy: 4060/10000 (41%)
# MEAN_TEACHER Test set: Average loss: 1.6275, Accuracy: 4090/10000 (41%)
#
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.779902
# STUDENT Test set: Average loss: 1.6308, Accuracy: 4104/10000 (41%)
# MEAN_TEACHER Test set: Average loss: 1.6185, Accuracy: 4192/10000 (42%)
#
# Train Epoch: 6 [44800/50000 (90%)]	Loss: 1.608832
# STUDENT Test set: Average loss: 1.6370, Accuracy: 4066/10000 (41%)
# MEAN_TEACHER Test set: Average loss: 1.6213, Accuracy: 4158/10000 (42%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.499398
# STUDENT Test set: Average loss: 1.6531, Accuracy: 4025/10000 (40%)
# MEAN_TEACHER Test set: Average loss: 1.6044, Accuracy: 4214/10000 (42%)
#
# Train Epoch: 7 [6400/50000 (13%)]	Loss: 1.631035
# STUDENT Test set: Average loss: 1.6288, Accuracy: 4150/10000 (42%)
# MEAN_TEACHER Test set: Average loss: 1.5991, Accuracy: 4279/10000 (43%)
#
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 1.591631
# STUDENT Test set: Average loss: 1.6220, Accuracy: 4184/10000 (42%)
# MEAN_TEACHER Test set: Average loss: 1.5952, Accuracy: 4301/10000 (43%)
#
# Train Epoch: 7 [19200/50000 (38%)]	Loss: 1.500674
# STUDENT Test set: Average loss: 1.6114, Accuracy: 4163/10000 (42%)
# MEAN_TEACHER Test set: Average loss: 1.5828, Accuracy: 4320/10000 (43%)
#
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.703410
# STUDENT Test set: Average loss: 1.5914, Accuracy: 4282/10000 (43%)
# MEAN_TEACHER Test set: Average loss: 1.5825, Accuracy: 4329/10000 (43%)
#
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 1.557981
# STUDENT Test set: Average loss: 1.5888, Accuracy: 4312/10000 (43%)
# MEAN_TEACHER Test set: Average loss: 1.5722, Accuracy: 4397/10000 (44%)
#
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.589285
# STUDENT Test set: Average loss: 1.5804, Accuracy: 4370/10000 (44%)
# MEAN_TEACHER Test set: Average loss: 1.5766, Accuracy: 4328/10000 (43%)
#
# Train Epoch: 7 [44800/50000 (90%)]	Loss: 1.489267
# STUDENT Test set: Average loss: 1.5763, Accuracy: 4308/10000 (43%)
# MEAN_TEACHER Test set: Average loss: 1.5670, Accuracy: 4415/10000 (44%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.686457
# STUDENT Test set: Average loss: 1.6085, Accuracy: 4214/10000 (42%)
# MEAN_TEACHER Test set: Average loss: 1.5537, Accuracy: 4438/10000 (44%)
#
# Train Epoch: 8 [6400/50000 (13%)]	Loss: 1.579096
# STUDENT Test set: Average loss: 1.5639, Accuracy: 4460/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5617, Accuracy: 4423/10000 (44%)
#
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 1.490173
# STUDENT Test set: Average loss: 1.5611, Accuracy: 4351/10000 (44%)
# MEAN_TEACHER Test set: Average loss: 1.5548, Accuracy: 4433/10000 (44%)
#
# Train Epoch: 8 [19200/50000 (38%)]	Loss: 1.662685
# STUDENT Test set: Average loss: 1.5545, Accuracy: 4391/10000 (44%)
# MEAN_TEACHER Test set: Average loss: 1.5523, Accuracy: 4418/10000 (44%)
#
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.652397
# STUDENT Test set: Average loss: 1.5736, Accuracy: 4387/10000 (44%)
# MEAN_TEACHER Test set: Average loss: 1.5513, Accuracy: 4472/10000 (45%)
#
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 1.526854
# STUDENT Test set: Average loss: 1.5629, Accuracy: 4357/10000 (44%)
# MEAN_TEACHER Test set: Average loss: 1.5483, Accuracy: 4471/10000 (45%)
#
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 1.497808
# STUDENT Test set: Average loss: 1.5463, Accuracy: 4402/10000 (44%)
# MEAN_TEACHER Test set: Average loss: 1.5347, Accuracy: 4501/10000 (45%)
#
# Train Epoch: 8 [44800/50000 (90%)]	Loss: 1.656479
# STUDENT Test set: Average loss: 1.5582, Accuracy: 4476/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5290, Accuracy: 4505/10000 (45%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.699631
# STUDENT Test set: Average loss: 1.5410, Accuracy: 4457/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5293, Accuracy: 4463/10000 (45%)
#
# Train Epoch: 9 [6400/50000 (13%)]	Loss: 1.678567
# STUDENT Test set: Average loss: 1.5351, Accuracy: 4491/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5263, Accuracy: 4559/10000 (46%)
#
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 1.750192
# STUDENT Test set: Average loss: 1.5256, Accuracy: 4492/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5193, Accuracy: 4553/10000 (46%)
#
# Train Epoch: 9 [19200/50000 (38%)]	Loss: 1.549882
# STUDENT Test set: Average loss: 1.5606, Accuracy: 4441/10000 (44%)
# MEAN_TEACHER Test set: Average loss: 1.5203, Accuracy: 4552/10000 (46%)
#
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.747969
# STUDENT Test set: Average loss: 1.5244, Accuracy: 4525/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5125, Accuracy: 4589/10000 (46%)
#
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 1.604015
# STUDENT Test set: Average loss: 1.5387, Accuracy: 4469/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5122, Accuracy: 4629/10000 (46%)
#
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 1.649863
# STUDENT Test set: Average loss: 1.5210, Accuracy: 4535/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.4992, Accuracy: 4625/10000 (46%)
#
# Train Epoch: 9 [44800/50000 (90%)]	Loss: 1.419392
# STUDENT Test set: Average loss: 1.5347, Accuracy: 4549/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.5026, Accuracy: 4611/10000 (46%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.600190
# STUDENT Test set: Average loss: 1.5236, Accuracy: 4502/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.4909, Accuracy: 4659/10000 (47%)
#
# Train Epoch: 10 [6400/50000 (13%)]	Loss: 1.521986
# STUDENT Test set: Average loss: 1.5173, Accuracy: 4564/10000 (46%)
# MEAN_TEACHER Test set: Average loss: 1.4955, Accuracy: 4642/10000 (46%)
#
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 1.741045
# STUDENT Test set: Average loss: 1.5078, Accuracy: 4605/10000 (46%)
# MEAN_TEACHER Test set: Average loss: 1.4950, Accuracy: 4624/10000 (46%)
#
# Train Epoch: 10 [19200/50000 (38%)]	Loss: 1.642419
# STUDENT Test set: Average loss: 1.5116, Accuracy: 4594/10000 (46%)
# MEAN_TEACHER Test set: Average loss: 1.4821, Accuracy: 4671/10000 (47%)
#
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.643215
# STUDENT Test set: Average loss: 1.5090, Accuracy: 4536/10000 (45%)
# MEAN_TEACHER Test set: Average loss: 1.4885, Accuracy: 4657/10000 (47%)
#
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 1.493024
# STUDENT Test set: Average loss: 1.4983, Accuracy: 4646/10000 (46%)
# MEAN_TEACHER Test set: Average loss: 1.4828, Accuracy: 4722/10000 (47%)
#
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 1.635400
# STUDENT Test set: Average loss: 1.4949, Accuracy: 4633/10000 (46%)
# MEAN_TEACHER Test set: Average loss: 1.4702, Accuracy: 4762/10000 (48%)
#
# Train Epoch: 10 [44800/50000 (90%)]	Loss: 1.451034
# STUDENT Test set: Average loss: 1.5020, Accuracy: 4604/10000 (46%)
# MEAN_TEACHER Test set: Average loss: 1.4686, Accuracy: 4792/10000 (48%)
